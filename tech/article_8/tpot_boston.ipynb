# %% [markdown]
# ## データの準備

# %%
from sklearn.datasets import load_boston
housing = load_boston()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(housing.data, housing.target,
                                                    train_size=0.75, test_size=0.25,
                                                    random_state=2018)

# %% [markdown]
# ## TPOT回帰を実践
# ### モジュールのインポート

# %%
from tpot import TPOTRegressor

# %% [markdown]
# ### 引数を入れてインスタンス生成

# %%
tpot = TPOTRegressor(generations=5, population_size=50, verbosity=2)

# %% [markdown]
# ### フィッティング実行

# %%
import time
t0 = time.time()
tpot.fit(X_train, y_train)
print(time.time() - t0)
# Out:
# Warning: xgboost.XGBRegressor is not available and will not be used by TPOT.
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=300, style=ProgressStyle(descript…
# Generation 1 - Current best internal CV score: -9.89499338132346
# Generation 2 - Current best internal CV score: -9.89499338132346
# Generation 3 - Current best internal CV score: -9.89499338132346
# Generation 4 - Current best internal CV score: -9.20830986451281
# Generation 5 - Current best internal CV score: -9.20830986451281
#
# Best pipeline: GradientBoostingRegressor(SelectFwe(input_matrix, alpha=0.003), alpha=0.75, learning_rate=0.1, loss=ls, max_depth=6, max_features=0.35000000000000003, min_samples_leaf=3, min_samples_split=18, n_estimators=100, subsample=0.7500000000000001)
# 126.89158344268799

# %%
print(tpot.score(X_test, y_test))
# Out:
# -7.550367333235424

# %%
tpot.fitted_pipeline_
# Out:
# Pipeline(memory=None,
#      steps=[('selectfwe', SelectFwe(alpha=0.003,
#      score_func=<function f_regression at 0x000002483C0147B8>)), ('gradientboostingregressor', GradientBoostingRegressor(alpha=0.75, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=6,
#              max_features=0.35...0.7500000000000001, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False))])

# %%
tpot.evaluated_individuals_
# Out:
# {'ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.7000000000000001, ElasticNetCV__tol=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -31.069535231284778},
#  'ExtraTreesRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=2, DecisionTreeRegressor__min_samples_leaf=1, DecisionTreeRegressor__min_samples_split=18), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.8, ExtraTreesRegressor__min_samples_leaf=11, ExtraTreesRegressor__min_samples_split=6, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -26.761995303942495},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=42, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -50.409659082521536},
#  'LassoLarsCV(input_matrix, LassoLarsCV__normalize=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -27.379117510544553},
#  'ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.3, ExtraTreesRegressor__min_samples_leaf=6, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -29.813390546702713},
#  'LinearSVR(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.01, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=1e-05)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -21.049549378946047},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=5, DecisionTreeRegressor__min_samples_leaf=11, DecisionTreeRegressor__min_samples_split=20)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -27.306121249838704},
#  'RandomForestRegressor(MinMaxScaler(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=1.0, RandomForestRegressor__min_samples_leaf=18, RandomForestRegressor__min_samples_split=2, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -22.55410863963304},
#  'KNeighborsRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=7, DecisionTreeRegressor__min_samples_leaf=2, DecisionTreeRegressor__min_samples_split=17), KNeighborsRegressor__n_neighbors=22, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -51.89040695302306},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.25, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=9, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.25)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -26.73083312129561},
#  'KNeighborsRegressor(MinMaxScaler(input_matrix), KNeighborsRegressor__n_neighbors=10, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -27.414761198728332},
#  'RandomForestRegressor(MinMaxScaler(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=10, RandomForestRegressor__min_samples_split=3, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -18.755659682908483},
#  'LinearSVR(FeatureAgglomeration(input_matrix, FeatureAgglomeration__affinity=euclidean, FeatureAgglomeration__linkage=complete), LinearSVR__C=20.0, LinearSVR__dual=False, LinearSVR__epsilon=0.01, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -129.88842575339788},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=20, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.8500000000000001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -17.453582183299925},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=63, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -68.44979561080832},
#  'RidgeCV(input_matrix)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -27.410670853211883},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=9, DecisionTreeRegressor__min_samples_leaf=2, DecisionTreeRegressor__min_samples_split=8)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -25.01080927844686},
#  'RandomForestRegressor(MinMaxScaler(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6000000000000001, RandomForestRegressor__min_samples_leaf=17, RandomForestRegressor__min_samples_split=15, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -21.859348624324717},
#  'ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.8500000000000001, ExtraTreesRegressor__min_samples_leaf=4, ExtraTreesRegressor__min_samples_split=2, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -14.542785848747027},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=29, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -58.313729703152056},
#  'LinearSVR(input_matrix, LinearSVR__C=0.01, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -55.837392971581195},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=20, DecisionTreeRegressor__min_samples_split=17)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -29.290507018571322},
#  'ExtraTreesRegressor(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.9000000000000001, RandomForestRegressor__min_samples_leaf=6, RandomForestRegressor__min_samples_split=17, RandomForestRegressor__n_estimators=100), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.15000000000000002, ExtraTreesRegressor__min_samples_leaf=19, ExtraTreesRegressor__min_samples_split=6, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -55.22359244171258},
#  'RidgeCV(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.2, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10))': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -27.90675288782983},
#  'LassoLarsCV(MinMaxScaler(input_matrix), LassoLarsCV__normalize=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -27.463400083477428},
#  'DecisionTreeRegressor(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.55, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=20, RandomForestRegressor__n_estimators=100), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=14)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -21.022275543014512},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=44, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -56.19525889583358},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=8, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=16, GradientBoostingRegressor__min_samples_split=12, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -79.08022827065224},
#  'LinearSVR(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.25, RandomForestRegressor__min_samples_leaf=18, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.1, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.0001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -17.639653037947095},
#  'RandomForestRegressor(StandardScaler(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.8, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=2, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -19.339644813596014},
#  'ExtraTreesRegressor(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.005), ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.2, ExtraTreesRegressor__min_samples_leaf=8, ExtraTreesRegressor__min_samples_split=5, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -40.9309181176169},
#  'GradientBoostingRegressor(PCA(input_matrix, PCA__iterated_power=4, PCA__svd_solver=randomized), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=1.0, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.3, GradientBoostingRegressor__min_samples_leaf=13, GradientBoostingRegressor__min_samples_split=17, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.15000000000000002)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -1466.8852404598877},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=20)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -22.012989676106002},
#  'RandomForestRegressor(ZeroCount(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.25, RandomForestRegressor__min_samples_leaf=9, RandomForestRegressor__min_samples_split=20, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -24.212896683005358},
#  'LinearSVR(input_matrix, LinearSVR__C=15.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=1e-05)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -53.676620199894934},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=4, GradientBoostingRegressor__max_features=0.35000000000000003, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -11.033210950162331},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -14.47118633841265},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=12, RandomForestRegressor__min_samples_split=5, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -19.517960471826484},
#  'ExtraTreesRegressor(PCA(input_matrix, PCA__iterated_power=6, PCA__svd_solver=randomized), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.7500000000000001, ExtraTreesRegressor__min_samples_leaf=12, ExtraTreesRegressor__min_samples_split=10, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -42.76858850651081},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=2, DecisionTreeRegressor__min_samples_leaf=6, DecisionTreeRegressor__min_samples_split=5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -36.62348584627959},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.7500000000000001, RandomForestRegressor__min_samples_leaf=10, RandomForestRegressor__min_samples_split=11, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -19.300912296543437},
#  'ElasticNetCV(MinMaxScaler(input_matrix), ElasticNetCV__l1_ratio=0.6000000000000001, ElasticNetCV__tol=1e-05)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -27.297726590026222},
#  'LassoLarsCV(input_matrix, LassoLarsCV__normalize=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -27.463400083477417},
#  'KNeighborsRegressor(Normalizer(input_matrix, Normalizer__norm=max), KNeighborsRegressor__n_neighbors=29, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=uniform)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=29, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=uniform)',),
#   'operator_count': 2,
#   'internal_cv_score': -58.52172972234392},
#  'KNeighborsRegressor(RobustScaler(input_matrix), KNeighborsRegressor__n_neighbors=29, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=uniform)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=29, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=uniform)',),
#   'operator_count': 2,
#   'internal_cv_score': -37.809048781525746},
#  'LassoLarsCV(MinMaxScaler(input_matrix), LassoLarsCV__normalize=False)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(MinMaxScaler(input_matrix), LassoLarsCV__normalize=True)',),
#   'operator_count': 2,
#   'internal_cv_score': -27.668590310152883},
#  'GradientBoostingRegressor(FastICA(input_matrix, FastICA__tol=0.75), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.25, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=9, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.25)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.25, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=9, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.25)',),
#   'operator_count': 2,
#   'internal_cv_score': -34.55448102947097},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=14)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.55, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=20, RandomForestRegressor__n_estimators=100), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=14)',),
#   'operator_count': 1,
#   'internal_cv_score': -21.34336081228617},
#  'RidgeCV(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.05, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10))': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 2,
#   'internal_cv_score': -28.181070637376905},
#  'RidgeCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.01, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=4, GradientBoostingRegressor__max_features=0.7000000000000001, GradientBoostingRegressor__min_samples_leaf=17, GradientBoostingRegressor__min_samples_split=17, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.8))': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 2,
#   'internal_cv_score': -19.949224309457005},
#  'KNeighborsRegressor(FeatureAgglomeration(input_matrix, FeatureAgglomeration__affinity=l2, FeatureAgglomeration__linkage=average), KNeighborsRegressor__n_neighbors=42, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=42, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance)',),
#   'operator_count': 2,
#   'internal_cv_score': -61.74966507648924},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=2, GradientBoostingRegressor__max_features=0.25, GradientBoostingRegressor__min_samples_leaf=13, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.8500000000000001)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': -84.19026039430247},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=12, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=uniform)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.7000000000000001, ElasticNetCV__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -48.351612682748545},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=3)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=20)',),
#   'operator_count': 1,
#   'internal_cv_score': -21.34336081228617},
#  'RandomForestRegressor(StandardScaler(ZeroCount(input_matrix)), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.25, RandomForestRegressor__min_samples_leaf=9, RandomForestRegressor__min_samples_split=20, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(ZeroCount(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.25, RandomForestRegressor__min_samples_leaf=9, RandomForestRegressor__min_samples_split=20, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 3,
#   'internal_cv_score': -24.213975305982256},
#  'RidgeCV(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=7, DecisionTreeRegressor__min_samples_leaf=10, DecisionTreeRegressor__min_samples_split=15))': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 2,
#   'internal_cv_score': -24.185355153340346},
#  'ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.7500000000000001, ExtraTreesRegressor__min_samples_leaf=12, ExtraTreesRegressor__min_samples_split=10, ExtraTreesRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesRegressor(PCA(input_matrix, PCA__iterated_power=6, PCA__svd_solver=randomized), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.7500000000000001, ExtraTreesRegressor__min_samples_leaf=12, ExtraTreesRegressor__min_samples_split=10, ExtraTreesRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -29.19051268247416},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=81, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=uniform)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=63, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=uniform)',),
#   'operator_count': 1,
#   'internal_cv_score': -68.24534353952248},
#  'ElasticNetCV(RidgeCV(input_matrix), ElasticNetCV__l1_ratio=0.7000000000000001, ElasticNetCV__tol=0.1)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.7000000000000001, ElasticNetCV__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -27.383206785148293},
#  'ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.8500000000000001, ExtraTreesRegressor__min_samples_leaf=8, ExtraTreesRegressor__min_samples_split=2, ExtraTreesRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.8500000000000001, ExtraTreesRegressor__min_samples_leaf=4, ExtraTreesRegressor__min_samples_split=2, ExtraTreesRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -18.17430155646597},
#  'LinearSVR(RBFSampler(input_matrix, RBFSampler__gamma=1.0), LinearSVR__C=15.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=1e-05)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=15.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=1e-05)',),
#   'operator_count': 2,
#   'internal_cv_score': -106.9945016311618},
#  'LinearSVR(Normalizer(input_matrix, Normalizer__norm=l1), LinearSVR__C=0.01, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=0.01, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -413.74318464134024},
#  'RandomForestRegressor(StandardScaler(input_matrix), RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.8, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=2, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(StandardScaler(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.8, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=2, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -20.55825488066955},
#  'LassoLarsCV(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.2), LassoLarsCV__normalize=True)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(input_matrix, LassoLarsCV__normalize=True)',),
#   'operator_count': 2,
#   'internal_cv_score': -28.891332385359583},
#  'RandomForestRegressor(MinMaxScaler(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.15000000000000002, RandomForestRegressor__min_samples_leaf=10, RandomForestRegressor__min_samples_split=3, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(MinMaxScaler(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=10, RandomForestRegressor__min_samples_split=3, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -37.425478709343075},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)',
#    'DecisionTreeRegressor(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.55, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=20, RandomForestRegressor__n_estimators=100), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=14)'),
#   'operator_count': 1,
#   'internal_cv_score': -21.48705463268703},
#  'ExtraTreesRegressor(CombineDFs(input_matrix, input_matrix), ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.8500000000000001, ExtraTreesRegressor__min_samples_leaf=4, ExtraTreesRegressor__min_samples_split=2, ExtraTreesRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.8500000000000001, ExtraTreesRegressor__min_samples_leaf=4, ExtraTreesRegressor__min_samples_split=2, ExtraTreesRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -14.006645281104861},
#  'LinearSVR(input_matrix, LinearSVR__C=20.0, LinearSVR__dual=False, LinearSVR__epsilon=0.01, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(FeatureAgglomeration(input_matrix, FeatureAgglomeration__affinity=euclidean, FeatureAgglomeration__linkage=complete), LinearSVR__C=20.0, LinearSVR__dual=False, LinearSVR__epsilon=0.01, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -131.64681954405484},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7000000000000001)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=8, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=16, GradientBoostingRegressor__min_samples_split=12, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.5)',),
#   'operator_count': 1,
#   'internal_cv_score': -19.835315468883458},
#  'LassoLarsCV(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.6500000000000001, RandomForestRegressor__min_samples_leaf=9, RandomForestRegressor__min_samples_split=10, RandomForestRegressor__n_estimators=100), LassoLarsCV__normalize=True)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(input_matrix, LassoLarsCV__normalize=True)',),
#   'operator_count': 2,
#   'internal_cv_score': -17.3702939470895},
#  'ElasticNetCV(MinMaxScaler(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.05)), ElasticNetCV__l1_ratio=0.6000000000000001, ElasticNetCV__tol=1e-05)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(MinMaxScaler(input_matrix), ElasticNetCV__l1_ratio=0.6000000000000001, ElasticNetCV__tol=1e-05)',),
#   'operator_count': 3,
#   'internal_cv_score': -28.94965540056004},
#  'DecisionTreeRegressor(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.15, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=20)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=20)',),
#   'operator_count': 2,
#   'internal_cv_score': -21.842286441173304},
#  'LinearSVR(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.15, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10), LinearSVR__C=0.01, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=0.01, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -54.67683208498072},
#  'GradientBoostingRegressor(StandardScaler(input_matrix), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.25, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=9, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.25)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.25, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=9, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.25)',),
#   'operator_count': 2,
#   'internal_cv_score': -26.677502211273673},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=5, DecisionTreeRegressor__min_samples_leaf=11, DecisionTreeRegressor__min_samples_split=8)': {'generation': 'INVALID',
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=5, DecisionTreeRegressor__min_samples_leaf=11, DecisionTreeRegressor__min_samples_split=20)',
#    'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=9, DecisionTreeRegressor__min_samples_leaf=2, DecisionTreeRegressor__min_samples_split=8)'),
#   'operator_count': 1,
#   'internal_cv_score': -27.306121249838704},
#  'RandomForestRegressor(ElasticNetCV(MinMaxScaler(input_matrix), ElasticNetCV__l1_ratio=0.25, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6000000000000001, RandomForestRegressor__min_samples_leaf=17, RandomForestRegressor__min_samples_split=15, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(MinMaxScaler(input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6000000000000001, RandomForestRegressor__min_samples_leaf=17, RandomForestRegressor__min_samples_split=15, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 3,
#   'internal_cv_score': -21.75527178634689},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=8, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.35000000000000003)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(input_matrix, LassoLarsCV__normalize=False)',),
#   'operator_count': 1,
#   'internal_cv_score': -12.554499639435637},
#  'ExtraTreesRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=1, DecisionTreeRegressor__min_samples_split=18), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.8, ExtraTreesRegressor__min_samples_leaf=11, ExtraTreesRegressor__min_samples_split=6, ExtraTreesRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=2, DecisionTreeRegressor__min_samples_leaf=1, DecisionTreeRegressor__min_samples_split=18), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.8, ExtraTreesRegressor__min_samples_leaf=11, ExtraTreesRegressor__min_samples_split=6, ExtraTreesRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -19.197823471114354},
#  'KNeighborsRegressor(ExtraTreesRegressor(MinMaxScaler(input_matrix), ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.6000000000000001, ExtraTreesRegressor__min_samples_leaf=16, ExtraTreesRegressor__min_samples_split=3, ExtraTreesRegressor__n_estimators=100), KNeighborsRegressor__n_neighbors=10, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsRegressor(MinMaxScaler(input_matrix), KNeighborsRegressor__n_neighbors=10, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance)',),
#   'operator_count': 3,
#   'internal_cv_score': -16.023523776899673},
#  'DecisionTreeRegressor(RandomForestRegressor(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.45, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=11, ExtraTreesRegressor__n_estimators=100), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.55, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=20, RandomForestRegressor__n_estimators=100), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=14)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.55, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=20, RandomForestRegressor__n_estimators=100), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=14)',),
#   'operator_count': 3,
#   'internal_cv_score': -21.58644753798452},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=7, DecisionTreeRegressor__min_samples_leaf=11, DecisionTreeRegressor__min_samples_split=20)': {'generation': 'INVALID',
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=5, DecisionTreeRegressor__min_samples_leaf=11, DecisionTreeRegressor__min_samples_split=20)',
#    'KNeighborsRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=7, DecisionTreeRegressor__min_samples_leaf=2, DecisionTreeRegressor__min_samples_split=17), KNeighborsRegressor__n_neighbors=22, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=uniform)'),
#   'operator_count': 1,
#   'internal_cv_score': -26.28522632919397},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=1, DecisionTreeRegressor__min_samples_split=20)': {'generation': 'INVALID',
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=20)',
#    'ExtraTreesRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=2, DecisionTreeRegressor__min_samples_leaf=1, DecisionTreeRegressor__min_samples_split=18), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.8, ExtraTreesRegressor__min_samples_leaf=11, ExtraTreesRegressor__min_samples_split=6, ExtraTreesRegressor__n_estimators=100)'),
#   'operator_count': 1,
#   'internal_cv_score': -21.76343008762108},
#  'KNeighborsRegressor(ExtraTreesRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=7, DecisionTreeRegressor__min_samples_leaf=2, DecisionTreeRegressor__min_samples_split=17), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.7000000000000001, ExtraTreesRegressor__min_samples_leaf=12, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), KNeighborsRegressor__n_neighbors=22, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=uniform)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=7, DecisionTreeRegressor__min_samples_leaf=2, DecisionTreeRegressor__min_samples_split=17), KNeighborsRegressor__n_neighbors=22, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=uniform)',),
#   'operator_count': 3,
#   'internal_cv_score': -49.17999925112368},
#  'RidgeCV(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.15, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10))': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.2, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10))',),
#   'operator_count': 2,
#   'internal_cv_score': -27.89668141108832},
#  'RidgeCV(RidgeCV(input_matrix))': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 2,
#   'internal_cv_score': -27.420037529084972},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.15000000000000002, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=12, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(input_matrix, LassoLarsCV__normalize=True)',),
#   'operator_count': 1,
#   'internal_cv_score': -26.437585134207758},
#  'LassoLarsCV(RobustScaler(input_matrix), LassoLarsCV__normalize=False)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(input_matrix, LassoLarsCV__normalize=False)',),
#   'operator_count': 2,
#   'internal_cv_score': -27.383056169864386},
#  'GradientBoostingRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=4, GradientBoostingRegressor__max_features=0.35000000000000003, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=4, GradientBoostingRegressor__max_features=0.35000000000000003, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)',),
#   'operator_count': 2,
#   'internal_cv_score': -9.89499338132346},
#  'RandomForestRegressor(SelectPercentile(input_matrix, SelectPercentile__percentile=26), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -18.247543937456907},
#  'RandomForestRegressor(MaxAbsScaler(input_matrix), RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.7500000000000001, RandomForestRegressor__min_samples_leaf=10, RandomForestRegressor__min_samples_split=11, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.7500000000000001, RandomForestRegressor__min_samples_leaf=10, RandomForestRegressor__min_samples_split=11, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -19.311140424515713},
# ...
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=3, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.35000000000000003)',),
#   'operator_count': 2,
#   'internal_cv_score': -18.81913755255002},
#  'RandomForestRegressor(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.2, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)': {'generation': 'INVALID',
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(ZeroCount(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.2, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10)), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -14.536034102424031},
#  'GradientBoostingRegressor(MaxAbsScaler(input_matrix), GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.8500000000000001)': {'generation': 'INVALID',
#   'mutation_count': 5,
#   'crossover_count': 1,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.8500000000000001)',),
#   'operator_count': 2,
#   'internal_cv_score': -15.51345644212538},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)': {'generation': 'INVALID',
#   'mutation_count': 4,
#   'crossover_count': 1,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)',
#    'GradientBoostingRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.01), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=4, GradientBoostingRegressor__max_features=0.35000000000000003, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)'),
#   'operator_count': 1,
#   'internal_cv_score': -19.485027302446873},
#  'GradientBoostingRegressor(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.01), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=8, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.35000000000000003)': {'generation': 'INVALID',
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.01), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=8, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.35000000000000003)',),
#   'operator_count': 2,
#   'internal_cv_score': -23.694716801078112},
#  'GradientBoostingRegressor(VarianceThreshold(LinearSVR(input_matrix, LinearSVR__C=0.5, LinearSVR__dual=False, LinearSVR__epsilon=0.1, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.1), VarianceThreshold__threshold=0.01), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=8, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.35000000000000003)': {'generation': 'INVALID',
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.01), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=8, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.35000000000000003)',),
#   'operator_count': 3,
#   'internal_cv_score': -13.333870391196218},
#  'DecisionTreeRegressor(RandomForestRegressor(PCA(input_matrix, PCA__iterated_power=9, PCA__svd_solver=randomized), RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.25, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=17, RandomForestRegressor__n_estimators=100), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=20)': {'generation': 'INVALID',
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.25, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=17, RandomForestRegressor__n_estimators=100), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=7, DecisionTreeRegressor__min_samples_split=20)',),
#   'operator_count': 3,
#   'internal_cv_score': -20.234415432975652},
#  'GradientBoostingRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=4, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)': {'generation': 'INVALID',
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=4, GradientBoostingRegressor__max_features=0.35000000000000003, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)',),
#   'operator_count': 2,
#   'internal_cv_score': -10.772143802333654},
#  'GradientBoostingRegressor(FeatureAgglomeration(input_matrix, FeatureAgglomeration__affinity=manhattan, FeatureAgglomeration__linkage=complete), GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7000000000000001)': {'generation': 'INVALID',
#   'mutation_count': 4,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7000000000000001)',),
#   'operator_count': 2,
#   'internal_cv_score': -68.05161064962665},
#  'LassoLarsCV(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), LassoLarsCV__normalize=False)': {'generation': 'INVALID',
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesRegressor(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.8500000000000001, ExtraTreesRegressor__min_samples_leaf=8, ExtraTreesRegressor__min_samples_split=2, ExtraTreesRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -18.450975573121905},
#  'GradientBoostingRegressor(Normalizer(SelectFwe(input_matrix, SelectFwe__alpha=0.003), Normalizer__norm=l1), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=6, GradientBoostingRegressor__max_features=0.35000000000000003, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)': {'generation': 'INVALID',
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(SelectFwe(input_matrix, SelectFwe__alpha=0.003), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=6, GradientBoostingRegressor__max_features=0.35000000000000003, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)',),
#   'operator_count': 3,
#   'internal_cv_score': -12.336324862055877},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)': {'generation': 'INVALID',
#   'mutation_count': 4,
#   'crossover_count': 2,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)',
#    'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=20, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.8500000000000001)'),
#   'operator_count': 1,
#   'internal_cv_score': -21.960634099542467},
#  'GradientBoostingRegressor(MinMaxScaler(input_matrix), GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.8500000000000001)': {'generation': 'INVALID',
#   'mutation_count': 5,
#   'crossover_count': 1,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.8500000000000001)',),
#   'operator_count': 2,
#   'internal_cv_score': -15.208302756801348},
#  'GradientBoostingRegressor(VarianceThreshold(SelectFwe(input_matrix, SelectFwe__alpha=0.038), VarianceThreshold__threshold=0.01), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=1.0, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=7, GradientBoostingRegressor__max_features=1.0, GradientBoostingRegressor__min_samples_leaf=14, GradientBoostingRegressor__min_samples_split=6, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.55)': {'generation': 'INVALID',
#   'mutation_count': 4,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(VarianceThreshold(SelectFwe(input_matrix, SelectFwe__alpha=0.038), VarianceThreshold__threshold=0.01), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=8, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.35000000000000003)',),
#   'operator_count': 3,
#   'internal_cv_score': -44.69646121439687}}

# %% [markdown]
# ### テストデータに適用

# %%
from scipy.stats import pearsonr
print('r = {:.3f}, p = {:.3f}'.format(*pearsonr(tpot.predict(X_test), y_test)))
# Out:
# r = 0.949, p = 0.000

# %%
from sklearn.metrics import r2_score
r2_score(tpot.predict(X_test), y_test)
# Out:
# 0.8904210023069816

# %% [markdown]
# ## 引数を変えて試す

# %% [markdown]
# ### 並列演算してみる

# %%
tpot = TPOTRegressor(generations=5, population_size=50, verbosity=2, n_jobs=-1)
t0 = time.time()
tpot.fit(X_train, y_train)
print(time.time() - t0)
# Out:
# Warning: xgboost.XGBRegressor is not available and will not be used by TPOT.
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=300, style=ProgressStyle(descript…
# Generation 1 - Current best internal CV score: -14.19487446474859
# Generation 2 - Current best internal CV score: -14.19487446474859
# Generation 3 - Current best internal CV score: -12.981679628725038
# Generation 4 - Current best internal CV score: -12.981679628725038
# Generation 5 - Current best internal CV score: -12.981679628725038
#
# Best pipeline: RandomForestRegressor(input_matrix, bootstrap=True, max_features=0.6500000000000001, min_samples_leaf=1, min_samples_split=15, n_estimators=100)
# 45.23204517364502

# %% [markdown]
# ### 世代と人口を増やしてみる

# %%
tpot = TPOTRegressor(verbosity=2, n_jobs=-1)
t0 = time.time()
tpot.fit(X_train, y_train)
print(time.time() - t0)
# Out:
# Warning: xgboost.XGBRegressor is not available and will not be used by TPOT.
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=10100, style=ProgressStyle(descri…
# Generation 1 - Current best internal CV score: -12.320834825896018
# Generation 2 - Current best internal CV score: -12.320834825896018
# Generation 3 - Current best internal CV score: -12.320834825896018
# Generation 4 - Current best internal CV score: -11.456809145038346
# Generation 5 - Current best internal CV score: -10.14467958287719
# Generation 6 - Current best internal CV score: -10.14467958287719
# Generation 7 - Current best internal CV score: -10.14467958287719
# Generation 8 - Current best internal CV score: -10.14467958287719
# Generation 9 - Current best internal CV score: -9.741908708600786
# Generation 10 - Current best internal CV score: -9.741908708600786
# Generation 11 - Current best internal CV score: -9.741908708600786
# Generation 12 - Current best internal CV score: -9.741908708600786
# Generation 13 - Current best internal CV score: -9.662321019789474
# Generation 14 - Current best internal CV score: -9.314097566243934
# Generation 15 - Current best internal CV score: -9.314097566243934
# Generation 16 - Current best internal CV score: -9.314097566243934
# Generation 17 - Current best internal CV score: -9.314097566243934
# Generation 18 - Current best internal CV score: -9.314097566243934
# Generation 19 - Current best internal CV score: -9.134748262727545
# Generation 20 - Current best internal CV score: -9.134748262727545
# Generation 21 - Current best internal CV score: -9.134748262727545
# Generation 22 - Current best internal CV score: -8.888048208010028
# Generation 23 - Current best internal CV score: -8.888048208010028
# Generation 24 - Current best internal CV score: -8.888048208010028
# Generation 25 - Current best internal CV score: -8.888048208010028
# Generation 26 - Current best internal CV score: -8.888048208010028
# Generation 27 - Current best internal CV score: -8.888048208010028
# Generation 28 - Current best internal CV score: -8.888048208010028
# Generation 29 - Current best internal CV score: -8.888048208010028
# Generation 30 - Current best internal CV score: -8.888048208010028
# Generation 31 - Current best internal CV score: -8.720687969908338
# Generation 32 - Current best internal CV score: -8.720687969908338
# Generation 33 - Current best internal CV score: -8.720687969908338
# Generation 34 - Current best internal CV score: -8.720687969908338
# Generation 35 - Current best internal CV score: -8.720687969908338
# Generation 36 - Current best internal CV score: -8.720687969908338
# Generation 37 - Current best internal CV score: -8.720687969908338
# Generation 38 - Current best internal CV score: -8.720687969908338
# Generation 39 - Current best internal CV score: -8.720687969908338
# Generation 40 - Current best internal CV score: -8.720687969908338
# Generation 41 - Current best internal CV score: -8.720687969908338
# Generation 42 - Current best internal CV score: -8.720687969908338
# Generation 43 - Current best internal CV score: -8.552614142850505
# Generation 44 - Current best internal CV score: -8.552614142850505
# Generation 45 - Current best internal CV score: -8.552614142850505
# Generation 46 - Current best internal CV score: -8.552614142850505
# Generation 47 - Current best internal CV score: -8.552614142850505
# Generation 48 - Current best internal CV score: -8.552614142850505
# Generation 49 - Current best internal CV score: -8.552614142850505
# Generation 50 - Current best internal CV score: -8.552614142850505
# Generation 51 - Current best internal CV score: -8.552614142850505
# Generation 52 - Current best internal CV score: -8.552614142850505
# Generation 53 - Current best internal CV score: -8.552614142850505
# Generation 54 - Current best internal CV score: -8.325780583348328
# Generation 55 - Current best internal CV score: -8.325780583348328
# Generation 56 - Current best internal CV score: -8.325780583348328
# Generation 57 - Current best internal CV score: -8.325780583348328
# Generation 58 - Current best internal CV score: -8.325780583348328
# Generation 59 - Current best internal CV score: -8.325780583348328
# Generation 60 - Current best internal CV score: -8.325780583348328
# Generation 61 - Current best internal CV score: -8.325780583348328
# Generation 62 - Current best internal CV score: -8.325780583348328
# Generation 63 - Current best internal CV score: -8.325780583348328
# Generation 64 - Current best internal CV score: -8.325780583348328
# Generation 65 - Current best internal CV score: -8.325780583348328
# Generation 66 - Current best internal CV score: -8.325780583348328
# Generation 67 - Current best internal CV score: -8.325780583348328
# Generation 68 - Current best internal CV score: -8.325780583348328
# Generation 69 - Current best internal CV score: -8.325780583348328
# Generation 70 - Current best internal CV score: -8.325780583348328
# Generation 71 - Current best internal CV score: -8.325780583348328
# Generation 72 - Current best internal CV score: -8.325780583348328
# Generation 73 - Current best internal CV score: -8.325780583348328
# Generation 74 - Current best internal CV score: -8.325780583348328
# Generation 75 - Current best internal CV score: -8.325780583348328
# Generation 76 - Current best internal CV score: -8.325780583348328
# Generation 77 - Current best internal CV score: -8.325780583348328
# Generation 78 - Current best internal CV score: -8.325780583348328
# Generation 79 - Current best internal CV score: -8.325780583348328
# Generation 80 - Current best internal CV score: -8.325780583348328
# Generation 81 - Current best internal CV score: -8.325780583348328
# Generation 82 - Current best internal CV score: -8.325780583348328
# Generation 83 - Current best internal CV score: -8.325780583348328
# Generation 84 - Current best internal CV score: -8.325780583348328
# Generation 85 - Current best internal CV score: -8.325780583348328
# Generation 86 - Current best internal CV score: -8.325780583348328
# Generation 87 - Current best internal CV score: -8.325780583348328
# Generation 88 - Current best internal CV score: -8.325780583348328
# Generation 89 - Current best internal CV score: -8.325780583348328
# Generation 90 - Current best internal CV score: -8.325780583348328
# Generation 91 - Current best internal CV score: -8.325780583348328
# Generation 92 - Current best internal CV score: -8.325780583348328
# Generation 93 - Current best internal CV score: -8.325780583348328
# Generation 94 - Current best internal CV score: -8.325780583348328
# Generation 95 - Current best internal CV score: -8.325780583348328
# Generation 96 - Current best internal CV score: -8.325780583348328
# Generation 97 - Current best internal CV score: -8.325780583348328
# Generation 98 - Current best internal CV score: -8.325780583348328
# Generation 99 - Current best internal CV score: -8.325780583348328
# Generation 100 - Current best internal CV score: -8.325780583348328
#
# Best pipeline: GradientBoostingRegressor(SelectFwe(MaxAbsScaler(RobustScaler(input_matrix)), alpha=0.031), alpha=0.95, learning_rate=0.1, loss=ls, max_depth=7, max_features=0.6500000000000001, min_samples_leaf=1, min_samples_split=14, n_estimators=100, subsample=0.6500000000000001)
# 1155.244289636612

# %%
print('r = {:.3f}, p = {:.3f}'.format(*pearsonr(tpot.predict(X_test), y_test)))
print('R2 = {:.3f}'.format(r2_score(tpot.predict(X_test), y_test)))
# Out:
# r = 0.954, p = 0.000
# R2 = 0.900

# %% [markdown]
# ## パイプラインの出力

# %%
tpot.export('tpot_boston_pipeline.py')
# Out:
# True
